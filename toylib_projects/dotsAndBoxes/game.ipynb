# %%
from toylib_projects.dotsAndBoxes import gametypes
from toylib_projects.dotsAndBoxes.interfaces import html_ipynb

# %%
game = gametypes.Game(m=3, n=3, interface_cls=html_ipynb.HTMLInterface)

# %%
game.render()
# Out:
# Rendering game with widget_id: b90f3aa5-8e86-4b2e-b2e5-d57578081c05
# Game state: {'m': 3, 'n': 3, 'next_player': 0, 'filled_vertical': [[False, False, False], [False, False, False], [False, False, False], [False, False, False]], 'filled_horizontal': [[False, False, False, False], [False, False, False, False], [False, False, False, False]], 'boxes_player_1': [[False, False, False], [False, False, False], [False, False, False]], 'boxes_player_2': [[False, False, False], [False, False, False], [False, False, False]]}
#         <div id="game-container-b90f3aa5-8e86-4b2e-b2e5-d57578081c05" style="background: white; padding: 20px; border-radius: 8px; display: inline-block;">
#             <h3>Dots and Boxes Game</h3>
#             <svg id="game-board-b90f3aa5-8e86-4b2e-b2e5-d57578081c05"></svg>
#             <div id="info-b90f3aa5-8e86-4b2e-b2e5-d57578081c05" style="margin-top: 20px;">
# ...
