# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
import numpy as np

# %%
tokenized = np.load('data/tokenized.npy', allow_pickle=True)  # Example shape

# %%
tokenized
# Out:
# array([array([ 7454,  2402,   257,   640,   612,   373,   257,  1310,  2933,
#                3706,  3932,    13,  3932,  6151,   284,  7301,   262,   995,
#                1088,   683,    13,   679,  2497,   867,  4998,  1243,    11,
#                 588,  4950,   410,  1386,   326,   547,   319,  3359,   287,
#                 257,  3650,    13,  1881,  1110,    11,  3932,   373,  6155,
#                 832,   262,  3650,   618,   339,  1625,  1973,   257,   845,
#                2041,   410,   589,    13,  1649,  3932,  2497,   340,   339,
#                 373, 24562,     0,   198,  1544,   531,    11,   564,   250,
#               22017,    11,   326,   318,   257,  1107,  4998,   410,   589,
#                   0,  1680,   314,  2822,   340,    30,   447,   251,   198,
#                 464,  6128, 13884, 13541,   290,   531,    11,   564,   250,
#                5189,  1781,   345,   460,    13,   921,   460,  1011,   340,
# ...

# %%
tokenizer.decode(tokenized[0])
# Out:
# "Once upon a time there was a little boy named Ben. Ben loved to explore the world around him. He saw many amazing things, like beautiful vases that were on display in a store. One day, Ben was walking through the store when he came across a very special vase. When Ben saw it he was amazed!\nHe said, “Wow, that is a really amazing vase! Can I buy it?”\nThe shopkeeper smiled and said, “Of course you can. You can take it home and show all your friends how amazing it is!”\nSo Ben took the vase home and he was so proud of it! He called his friends over and showed them the amazing vase. All his friends thought the vase was beautiful and couldn't believe how lucky Ben was.\nAnd that's how Ben found an amazing vase in the store!"
