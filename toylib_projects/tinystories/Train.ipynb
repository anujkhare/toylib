# %%
import datetime
import jax
import optax

# import local modules
from toylib_projects.tinystories import analyze
from toylib_projects.tinystories import data
from toylib_projects.tinystories import decoder_only_model
from toylib_projects.tinystories import experiment
from toylib_projects.tinystories import logger
from toylib_projects.tinystories import train
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
class DummyDataset(data.BatchedTokenizedDataset):
    def __init__(self, vocab_size: int = 50257, seq_len: int = 16, batch_size: int = 8):
        self.v = vocab_size
        self.t = seq_len
        self.b = batch_size

    def _get_dataset_iterator(self):
        pass

    def __next__(self):
        return {
            "inputs": jax.random.randint(jax.random.PRNGKey(0), (self.b, self.t), 0, self.v),
            "targets": jax.random.randint(jax.random.PRNGKey(1), (self.b, self.t), 0, self.v),
        }

# %%
batch_size, seq_len, vocab_size = 16, 1024, 50257
depth = 12


train_task = experiment.Task(
    name="train_owt",
    dataset=DummyDataset(vocab_size=vocab_size, seq_len=seq_len, batch_size=batch_size),
)
version = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
exp = experiment.Experiment(
    model_config=train.get_model_config(depth=depth, seq_len=seq_len, vocab_size=vocab_size),
    training_config=experiment.TrainingConfig(
        batch_size=batch_size,
    ),
    checkpoint_config=experiment.CheckpointConfig(
        checkpoint_dir=f"/Users/anuj/Desktop/code/toylib/checkpoints/{version}/",
        save_interval_steps=10,
    ),
    train_task=train_task,
    logger_config=experiment.LoggerConfig(
        log_dir=f"tensorboard_logs/{version}/",
        logger_cls=logger.StdoutLogger,

    ),
)
# Out:
# WARNING:absl:Configured `CheckpointManager` using deprecated legacy API. Please follow the instructions at https://orbax.readthedocs.io/en/latest/guides/checkpoint/api_refactor.html to migrate.
# num_layers: 12
# model_dim: 768
# num_heads: 6
# num_kv_heads: 6

# %%
# Visualize a few batches
for ix, batch in enumerate(train_task.dataset):
    print(batch)
    if ix == 1:
        break
# Out:
# {'inputs': Array([[26420, 38856,   963, ...,  7417, 23953, 15920],
#        [27772, 36015,  4738, ..., 14243, 39694, 32359],
#        [ 6412, 22050, 37697, ..., 25417,   198, 34683],
#        ...,
#        [ 6925, 28091, 14897, ..., 14298, 39898, 22641],
#        [ 9550,  6284, 36870, ..., 36869, 10513, 41584],
#        [35446, 41860, 47409, ..., 17826, 21165, 37133]], dtype=int32), 'targets': Array([[ 1584, 11710, 27314, ..., 34114, 32819,  9406],
#        [33200, 41224,  2342, ..., 40552, 32351,  5342],
#        [15846, 35807, 45198, ..., 10718, 21056,  1123],
#        ...,
#        [25199,  5048, 45727, ..., 45540, 32459,  7211],
#        [44277, 41659, 41142, ...,  9355, 27861, 27193],
#        [33669, 11907, 35940, ..., 17120,  3090, 25011]], dtype=int32)}
# {'inputs': Array([[26420, 38856,   963, ...,  7417, 23953, 15920],
#        [27772, 36015,  4738, ..., 14243, 39694, 32359],
#        [ 6412, 22050, 37697, ..., 25417,   198, 34683],
#        ...,
#        [ 6925, 28091, 14897, ..., 14298, 39898, 22641],
#        [ 9550,  6284, 36870, ..., 36869, 10513, 41584],
#        [35446, 41860, 47409, ..., 17826, 21165, 37133]], dtype=int32), 'targets': Array([[ 1584, 11710, 27314, ..., 34114, 32819,  9406],
#        [33200, 41224,  2342, ..., 40552, 32351,  5342],
#        [15846, 35807, 45198, ..., 10718, 21056,  1123],
#        ...,
#        [25199,  5048, 45727, ..., 45540, 32459,  7211],
#        [44277, 41659, 41142, ...,  9355, 27861, 27193],
#        [33669, 11907, 35940, ..., 17120,  3090, 25011]], dtype=int32)}

# %%
exp.init_state()

# %%
df_stats = analyze.print_param_sizes(exp.model, depth=3)
df_stats
# Out:
# Total Parameters: 164488704 (657954816.00)
#              level_0   level_1       level_2    params  n_bytes_divided
# 0            .blocks       [0]  .causal_attn   2555904       10223616.0
# 1            .blocks       [0]          .mlp   4718592       18874368.0
# 2            .blocks      [10]  .causal_attn   2555904       10223616.0
# 3            .blocks      [10]          .mlp   4718592       18874368.0
# 4            .blocks      [11]  .causal_attn   2555904       10223616.0
# 5            .blocks      [11]          .mlp   4718592       18874368.0
# 6            .blocks       [1]  .causal_attn   2555904       10223616.0
# 7            .blocks       [1]          .mlp   4718592       18874368.0
# 8            .blocks       [2]  .causal_attn   2555904       10223616.0
# 9            .blocks       [2]          .mlp   4718592       18874368.0
# 10           .blocks       [3]  .causal_attn   2555904       10223616.0
# 11           .blocks       [3]          .mlp   4718592       18874368.0
# 12           .blocks       [4]  .causal_attn   2555904       10223616.0
# 13           .blocks       [4]          .mlp   4718592       18874368.0
# 14           .blocks       [5]  .causal_attn   2555904       10223616.0
# 15           .blocks       [5]          .mlp   4718592       18874368.0
# 16           .blocks       [6]  .causal_attn   2555904       10223616.0
# 17           .blocks       [6]          .mlp   4718592       18874368.0
# 18           .blocks       [7]  .causal_attn   2555904       10223616.0
# 19           .blocks       [7]          .mlp   4718592       18874368.0
# 20           .blocks       [8]  .causal_attn   2555904       10223616.0
# 21           .blocks       [8]          .mlp   4718592       18874368.0
# 22           .blocks       [9]  .causal_attn   2555904       10223616.0
# 23           .blocks       [9]          .mlp   4718592       18874368.0
# 24  .embedding_layer  .weights                38597376      154389504.0
# 25     .output_layer  .weights                38597376      154389504.0

# %%
def one_step(model, batch):
  opt = optax.adam(learning_rate=1e-4)
  opt_state = opt.init(model)

  inputs, mask, targets = batch['inputs'], jax.numpy.ones_like(batch['inputs']), batch['targets']
  val, grad = jax.value_and_grad(decoder_only_model.train_step)(model, inputs, mask, targets)
  updates, opt_state = opt.update(grad, opt_state)
  model = optax.apply_updates(model, updates)
  return val, grad

# %%
analyze.print_xla_memory_analysis(one_step, exp.model, batch)
# Out:
# --- XLA Compilation Estimate ---
# Arguments (Params + Batch):	624.60 MiB
# Output (Grads + Loss):	627.48 MiB
# Temp/Activations (Peak):	35763.56 MiB
# Total Peak Memory:	36388.16 MiB

# %%
exp.save_checkpoint()

# %%
exp.restore_checkpoint(step=0)

# %%
exp.outer_loop()
