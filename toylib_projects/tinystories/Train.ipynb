# %%
import datetime
import jax

# import local modules
from toylib_projects.tinystories import data
from toylib_projects.tinystories import decoder_only_model
from toylib_projects.tinystories import experiment
from toylib_projects.tinystories import logger
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
class DummyDataset(data.BatchedTokenizedDataset):
    def __init__(self, vocab_size: int = 50257, seq_len: int = 16, batch_size: int = 8):
        self.v = vocab_size
        self.t = seq_len
        self.b = batch_size

    def _get_dataset_iterator(self):
        pass

    def __next__(self):
        return {
            "inputs": jax.random.randint(jax.random.PRNGKey(0), (self.b, self.t), 0, self.v),
            "targets": jax.random.randint(jax.random.PRNGKey(1), (self.b, self.t), 0, self.v),
        }

# %%
B, T, V = 8, 128, 100

train_task = experiment.Task(
    name="train_owt",
    dataset=DummyDataset(vocab_size=V, seq_len=T, batch_size=B),
)
version = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
exp = experiment.Experiment(
    model_config=decoder_only_model.ModelConfig(
        vocab_size=V,  # GPT-2 tokenizer vocab size
        num_layers=1,
        qkv_dim=8,
        num_heads=1,
        seq_len=T,
    ),
    training_config=experiment.TrainingConfig(
        batch_size=B,
    ),
    checkpoint_config=experiment.CheckpointConfig(
        checkpoint_dir=f"/Users/anuj/Desktop/code/toylib/checkpoints/{version}/",
        save_interval_steps=10,
    ),
    train_task=train_task,
    logger_config=experiment.LoggerConfig(
        log_dir=f"tensorboard_logs/{version}/",
        logger_cls=logger.StdoutLogger,

    ),
)
# Out:
# WARNING:absl:Configured `CheckpointManager` using deprecated legacy API. Please follow the instructions at https://orbax.readthedocs.io/en/latest/guides/checkpoint/api_refactor.html to migrate.

# %%
# Visualize a few batches
for ix, batch in enumerate(train_task.dataset):
    print(batch)
    if ix == 1:
        break
# Out:
# {'inputs': Array([[89,  0, 12, ..., 90, 90, 96],
#        [ 2,  5, 61, ..., 27,  2, 13],
#        [86, 65, 97, ..., 44, 42, 47],
#        ...,
#        [90, 88, 12, ..., 73, 24, 34],
#        [17, 83, 68, ..., 14, 70, 43],
#        [73, 93, 82, ..., 37, 87, 29]], dtype=int32), 'targets': Array([[96, 27, 40, ..., 75, 23, 95],
#        [77, 82, 42, ..., 61, 75, 78],
#        [76, 44, 27, ..., 16, 17,  2],
#        ...,
#        [67, 22, 54, ..., 51, 41, 38],
#        [50, 64, 22, ..., 61, 52, 81],
#        [13, 32, 95, ..., 13, 11, 10]], dtype=int32)}
# {'inputs': Array([[89,  0, 12, ..., 90, 90, 96],
#        [ 2,  5, 61, ..., 27,  2, 13],
#        [86, 65, 97, ..., 44, 42, 47],
#        ...,
#        [90, 88, 12, ..., 73, 24, 34],
#        [17, 83, 68, ..., 14, 70, 43],
#        [73, 93, 82, ..., 37, 87, 29]], dtype=int32), 'targets': Array([[96, 27, 40, ..., 75, 23, 95],
#        [77, 82, 42, ..., 61, 75, 78],
#        [76, 44, 27, ..., 16, 17,  2],
#        ...,
#        [67, 22, 54, ..., 51, 41, 38],
#        [50, 64, 22, ..., 61, 52, 81],
#        [13, 32, 95, ..., 13, 11, 10]], dtype=int32)}

# %%
exp.init_state()

# %%
exp.save_checkpoint()

# %%
exp.outer_loop()
# Out:
# Step 0: {'train/loss': 5.164445877075195, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.7542878e-05, dtype=float32), 'gradients/1/mean': Array(0., dtype=float32), 'gradients/2/mean': Array(0., dtype=float32)}
# Step 1: {'train/loss': 5.158703327178955, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.9082629e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016221, dtype=float32), 'gradients/2/mean': Array(-2.0828942e-05, dtype=float32)}
# Step 2: {'train/loss': 5.152964115142822, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.9478295e-05, dtype=float32), 'gradients/1/mean': Array(-0.00018093, dtype=float32), 'gradients/2/mean': Array(-1.8302148e-05, dtype=float32)}
# Step 3: {'train/loss': 5.1472272872924805, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.0226697e-05, dtype=float32), 'gradients/1/mean': Array(-0.00019057, dtype=float32), 'gradients/2/mean': Array(-5.9987633e-06, dtype=float32)}
# Step 4: {'train/loss': 5.1414899826049805, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1052181e-05, dtype=float32), 'gradients/1/mean': Array(-0.00019739, dtype=float32), 'gradients/2/mean': Array(-3.8172057e-06, dtype=float32)}
# Step 5: {'train/loss': 5.135753631591797, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1994443e-05, dtype=float32), 'gradients/1/mean': Array(-0.00020296, dtype=float32), 'gradients/2/mean': Array(-1.0122702e-05, dtype=float32)}
# Step 6: {'train/loss': 5.1300153732299805, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.2918164e-05, dtype=float32), 'gradients/1/mean': Array(-0.00020773, dtype=float32), 'gradients/2/mean': Array(-1.9247283e-05, dtype=float32)}
# Step 7: {'train/loss': 5.124277591705322, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3717694e-05, dtype=float32), 'gradients/1/mean': Array(-0.00021171, dtype=float32), 'gradients/2/mean': Array(-2.3365697e-05, dtype=float32)}
# Step 8: {'train/loss': 5.118537902832031, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.4362364e-05, dtype=float32), 'gradients/1/mean': Array(-0.00021453, dtype=float32), 'gradients/2/mean': Array(-2.5641544e-05, dtype=float32)}
# Step 9: {'train/loss': 5.112793922424316, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.4881589e-05, dtype=float32), 'gradients/1/mean': Array(-0.00021518, dtype=float32), 'gradients/2/mean': Array(-2.7367549e-05, dtype=float32)}
# Step 10: {'train/loss': 5.107049942016602, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.5332727e-05, dtype=float32), 'gradients/1/mean': Array(-0.00021218, dtype=float32), 'gradients/2/mean': Array(-2.8749395e-05, dtype=float32)}
# Step 11: {'train/loss': 5.101300239562988, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.5761015e-05, dtype=float32), 'gradients/1/mean': Array(-0.0002056, dtype=float32), 'gradients/2/mean': Array(-2.9764571e-05, dtype=float32)}
# Step 12: {'train/loss': 5.095549583435059, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6159756e-05, dtype=float32), 'gradients/1/mean': Array(-0.00019759, dtype=float32), 'gradients/2/mean': Array(-3.0420128e-05, dtype=float32)}
# Step 13: {'train/loss': 5.089792251586914, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.647959e-05, dtype=float32), 'gradients/1/mean': Array(-0.00018895, dtype=float32), 'gradients/2/mean': Array(-3.0797204e-05, dtype=float32)}
# Step 14: {'train/loss': 5.084033966064453, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6683834e-05, dtype=float32), 'gradients/1/mean': Array(-0.00017982, dtype=float32), 'gradients/2/mean': Array(-3.101692e-05, dtype=float32)}
# Step 15: {'train/loss': 5.078269004821777, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6771542e-05, dtype=float32), 'gradients/1/mean': Array(-0.00017119, dtype=float32), 'gradients/2/mean': Array(-3.118944e-05, dtype=float32)}
# Step 16: {'train/loss': 5.072498798370361, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6764905e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016428, dtype=float32), 'gradients/2/mean': Array(-3.13918e-05, dtype=float32)}
# Step 17: {'train/loss': 5.066723346710205, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6693837e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015957, dtype=float32), 'gradients/2/mean': Array(-3.167841e-05, dtype=float32)}
# Step 18: {'train/loss': 5.06094217300415, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6586618e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015679, dtype=float32), 'gradients/2/mean': Array(-3.21036e-05, dtype=float32)}
# Step 19: {'train/loss': 5.0551557540893555, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.646591e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015545, dtype=float32), 'gradients/2/mean': Array(-3.2743705e-05, dtype=float32)}
# Step 20: {'train/loss': 5.049360752105713, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6348313e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015501, dtype=float32), 'gradients/2/mean': Array(-3.3715427e-05, dtype=float32)}
# Step 21: {'train/loss': 5.0435590744018555, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6245636e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015492, dtype=float32), 'gradients/2/mean': Array(-3.517884e-05, dtype=float32)}
# Step 22: {'train/loss': 5.037750244140625, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6166326e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015484, dtype=float32), 'gradients/2/mean': Array(-3.729383e-05, dtype=float32)}
# Step 23: {'train/loss': 5.031932830810547, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.611636e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015462, dtype=float32), 'gradients/2/mean': Array(-4.012278e-05, dtype=float32)}
# Step 24: {'train/loss': 5.026108741760254, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6099777e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015428, dtype=float32), 'gradients/2/mean': Array(-4.353258e-05, dtype=float32)}
# Step 25: {'train/loss': 5.020273208618164, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6118892e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015396, dtype=float32), 'gradients/2/mean': Array(-4.718477e-05, dtype=float32)}
# Step 26: {'train/loss': 5.014432430267334, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.617438e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015383, dtype=float32), 'gradients/2/mean': Array(-5.0658186e-05, dtype=float32)}
# Step 27: {'train/loss': 5.008581161499023, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.626515e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015409, dtype=float32), 'gradients/2/mean': Array(-5.366091e-05, dtype=float32)}
# Step 28: {'train/loss': 5.002720355987549, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6388361e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015492, dtype=float32), 'gradients/2/mean': Array(-5.617828e-05, dtype=float32)}
# Step 29: {'train/loss': 4.996851921081543, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.653961e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015644, dtype=float32), 'gradients/2/mean': Array(-5.8362813e-05, dtype=float32)}
# Step 30: {'train/loss': 4.990972518920898, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6713235e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015866, dtype=float32), 'gradients/2/mean': Array(-6.0250815e-05, dtype=float32)}
# Step 31: {'train/loss': 4.985084056854248, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.690277e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016138, dtype=float32), 'gradients/2/mean': Array(-6.166011e-05, dtype=float32)}
# Step 32: {'train/loss': 4.979184627532959, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.7101378e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016428, dtype=float32), 'gradients/2/mean': Array(-6.233662e-05, dtype=float32)}
# Step 33: {'train/loss': 4.973277568817139, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.73022e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016698, dtype=float32), 'gradients/2/mean': Array(-6.2131585e-05, dtype=float32)}
# Step 34: {'train/loss': 4.96735954284668, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.749867e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016914, dtype=float32), 'gradients/2/mean': Array(-6.1083905e-05, dtype=float32)}
# Step 35: {'train/loss': 4.961431503295898, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.7684555e-05, dtype=float32), 'gradients/1/mean': Array(-0.00017054, dtype=float32), 'gradients/2/mean': Array(-5.940141e-05, dtype=float32)}
# Step 36: {'train/loss': 4.955492973327637, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.785422e-05, dtype=float32), 'gradients/1/mean': Array(-0.00017108, dtype=float32), 'gradients/2/mean': Array(-5.738203e-05, dtype=float32)}
# Step 37: {'train/loss': 4.9495463371276855, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.8002467e-05, dtype=float32), 'gradients/1/mean': Array(-0.0001708, dtype=float32), 'gradients/2/mean': Array(-5.532284e-05, dtype=float32)}
# Step 38: {'train/loss': 4.9435882568359375, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.8124703e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016984, dtype=float32), 'gradients/2/mean': Array(-5.3454678e-05, dtype=float32)}
# Step 39: {'train/loss': 4.9376220703125, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.8217088e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016842, dtype=float32), 'gradients/2/mean': Array(-5.191804e-05, dtype=float32)}
# Step 40: {'train/loss': 4.931647300720215, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.8276634e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016681, dtype=float32), 'gradients/2/mean': Array(-5.0770235e-05, dtype=float32)}
# Step 41: {'train/loss': 4.925661087036133, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.8301309e-05, dtype=float32), 'gradients/1/mean': Array(-0.0001652, dtype=float32), 'gradients/2/mean': Array(-5.0006034e-05, dtype=float32)}
# Step 42: {'train/loss': 4.919666767120361, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.8290247e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016366, dtype=float32), 'gradients/2/mean': Array(-4.957881e-05, dtype=float32)}
# Step 43: {'train/loss': 4.9136643409729, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.8243712e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016207, dtype=float32), 'gradients/2/mean': Array(-4.941482e-05, dtype=float32)}
# Step 44: {'train/loss': 4.907654762268066, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.8163306e-05, dtype=float32), 'gradients/1/mean': Array(-0.0001602, dtype=float32), 'gradients/2/mean': Array(-4.942173e-05, dtype=float32)}
# Step 45: {'train/loss': 4.901634216308594, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.805154e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015782, dtype=float32), 'gradients/2/mean': Array(-4.949597e-05, dtype=float32)}
# Step 46: {'train/loss': 4.895606994628906, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.791184e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015476, dtype=float32), 'gradients/2/mean': Array(-4.953181e-05, dtype=float32)}
# Step 47: {'train/loss': 4.8895745277404785, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.7748134e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015095, dtype=float32), 'gradients/2/mean': Array(-4.943147e-05, dtype=float32)}
# Step 48: {'train/loss': 4.883533954620361, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.7564298e-05, dtype=float32), 'gradients/1/mean': Array(-0.0001464, dtype=float32), 'gradients/2/mean': Array(-4.911635e-05, dtype=float32)}
# Step 49: {'train/loss': 4.8774871826171875, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.736382e-05, dtype=float32), 'gradients/1/mean': Array(-0.00014116, dtype=float32), 'gradients/2/mean': Array(-4.853366e-05, dtype=float32)}
# Step 50: {'train/loss': 4.871433258056641, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.714937e-05, dtype=float32), 'gradients/1/mean': Array(-0.00013534, dtype=float32), 'gradients/2/mean': Array(-4.7658446e-05, dtype=float32)}
# Step 51: {'train/loss': 4.8653740882873535, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6922517e-05, dtype=float32), 'gradients/1/mean': Array(-0.00012904, dtype=float32), 'gradients/2/mean': Array(-4.6491496e-05, dtype=float32)}
# Step 52: {'train/loss': 4.859312057495117, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6683805e-05, dtype=float32), 'gradients/1/mean': Array(-0.00012238, dtype=float32), 'gradients/2/mean': Array(-4.5052053e-05, dtype=float32)}
# Step 53: {'train/loss': 4.853243827819824, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.643282e-05, dtype=float32), 'gradients/1/mean': Array(-0.00011545, dtype=float32), 'gradients/2/mean': Array(-4.337015e-05, dtype=float32)}
# Step 54: {'train/loss': 4.847174167633057, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.6168673e-05, dtype=float32), 'gradients/1/mean': Array(-0.00010833, dtype=float32), 'gradients/2/mean': Array(-4.1478284e-05, dtype=float32)}
# Step 55: {'train/loss': 4.841100692749023, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.5890347e-05, dtype=float32), 'gradients/1/mean': Array(-0.00010109, dtype=float32), 'gradients/2/mean': Array(-3.9404415e-05, dtype=float32)}
# Step 56: {'train/loss': 4.835025310516357, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.5597321e-05, dtype=float32), 'gradients/1/mean': Array(-9.3761635e-05, dtype=float32), 'gradients/2/mean': Array(-3.7167236e-05, dtype=float32)}
# Step 57: {'train/loss': 4.828948020935059, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.5289935e-05, dtype=float32), 'gradients/1/mean': Array(-8.636528e-05, dtype=float32), 'gradients/2/mean': Array(-3.4773668e-05, dtype=float32)}
# Step 58: {'train/loss': 4.822869300842285, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.4969677e-05, dtype=float32), 'gradients/1/mean': Array(-7.8906734e-05, dtype=float32), 'gradients/2/mean': Array(-3.2218064e-05, dtype=float32)}
# Step 59: {'train/loss': 4.8167924880981445, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.4639314e-05, dtype=float32), 'gradients/1/mean': Array(-7.138626e-05, dtype=float32), 'gradients/2/mean': Array(-2.9483774e-05, dtype=float32)}
# Step 60: {'train/loss': 4.8107147216796875, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.4302906e-05, dtype=float32), 'gradients/1/mean': Array(-6.380373e-05, dtype=float32), 'gradients/2/mean': Array(-2.6543657e-05, dtype=float32)}
# Step 61: {'train/loss': 4.8046393394470215, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3965504e-05, dtype=float32), 'gradients/1/mean': Array(-5.6163386e-05, dtype=float32), 'gradients/2/mean': Array(-2.3361195e-05, dtype=float32)}
# Step 62: {'train/loss': 4.798566818237305, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3633042e-05, dtype=float32), 'gradients/1/mean': Array(-4.847857e-05, dtype=float32), 'gradients/2/mean': Array(-1.9891675e-05, dtype=float32)}
# Step 63: {'train/loss': 4.792497158050537, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.331183e-05, dtype=float32), 'gradients/1/mean': Array(-4.077771e-05, dtype=float32), 'gradients/2/mean': Array(-1.6083548e-05, dtype=float32)}
# Step 64: {'train/loss': 4.786432266235352, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3008082e-05, dtype=float32), 'gradients/1/mean': Array(-3.3111297e-05, dtype=float32), 'gradients/2/mean': Array(-1.1880031e-05, dtype=float32)}
# Step 65: {'train/loss': 4.780372142791748, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.2727321e-05, dtype=float32), 'gradients/1/mean': Array(-2.5558778e-05, dtype=float32), 'gradients/2/mean': Array(-7.2248167e-06, dtype=float32)}
# Step 66: {'train/loss': 4.774317741394043, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.2473823e-05, dtype=float32), 'gradients/1/mean': Array(-1.823176e-05, dtype=float32), 'gradients/2/mean': Array(-2.0671487e-06, dtype=float32)}
# Step 67: {'train/loss': 4.768270492553711, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.2250235e-05, dtype=float32), 'gradients/1/mean': Array(-1.1270948e-05, dtype=float32), 'gradients/2/mean': Array(3.6277306e-06, dtype=float32)}
# Step 68: {'train/loss': 4.762230396270752, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.2057688e-05, dtype=float32), 'gradients/1/mean': Array(-4.835245e-06, dtype=float32), 'gradients/2/mean': Array(9.868829e-06, dtype=float32)}
# Step 69: {'train/loss': 4.756196975708008, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.189601e-05, dtype=float32), 'gradients/1/mean': Array(9.150963e-07, dtype=float32), 'gradients/2/mean': Array(1.6628906e-05, dtype=float32)}
# Step 70: {'train/loss': 4.750173091888428, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1764301e-05, dtype=float32), 'gradients/1/mean': Array(5.8381356e-06, dtype=float32), 'gradients/2/mean': Array(2.383686e-05, dtype=float32)}
# Step 71: {'train/loss': 4.744156837463379, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.166151e-05, dtype=float32), 'gradients/1/mean': Array(9.827706e-06, dtype=float32), 'gradients/2/mean': Array(3.137648e-05, dtype=float32)}
# Step 72: {'train/loss': 4.738149642944336, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1586631e-05, dtype=float32), 'gradients/1/mean': Array(1.2825726e-05, dtype=float32), 'gradients/2/mean': Array(3.9093567e-05, dtype=float32)}
# Step 73: {'train/loss': 4.732151508331299, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1538983e-05, dtype=float32), 'gradients/1/mean': Array(1.4827323e-05, dtype=float32), 'gradients/2/mean': Array(4.6812278e-05, dtype=float32)}
# Step 74: {'train/loss': 4.726164817810059, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1517995e-05, dtype=float32), 'gradients/1/mean': Array(1.5879323e-05, dtype=float32), 'gradients/2/mean': Array(5.435702e-05, dtype=float32)}
# Step 75: {'train/loss': 4.720184326171875, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1523116e-05, dtype=float32), 'gradients/1/mean': Array(1.6072e-05, dtype=float32), 'gradients/2/mean': Array(6.157324e-05, dtype=float32)}
# Step 76: {'train/loss': 4.714217185974121, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1553702e-05, dtype=float32), 'gradients/1/mean': Array(1.5526603e-05, dtype=float32), 'gradients/2/mean': Array(6.83417e-05, dtype=float32)}
# Step 77: {'train/loss': 4.708261013031006, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1609087e-05, dtype=float32), 'gradients/1/mean': Array(1.4378446e-05, dtype=float32), 'gradients/2/mean': Array(7.458354e-05, dtype=float32)}
# Step 78: {'train/loss': 4.702314376831055, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.168854e-05, dtype=float32), 'gradients/1/mean': Array(1.2757268e-05, dtype=float32), 'gradients/2/mean': Array(8.0256956e-05, dtype=float32)}
# Step 79: {'train/loss': 4.696379661560059, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1791528e-05, dtype=float32), 'gradients/1/mean': Array(1.0768548e-05, dtype=float32), 'gradients/2/mean': Array(8.534907e-05, dtype=float32)}
# Step 80: {'train/loss': 4.690458297729492, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1917722e-05, dtype=float32), 'gradients/1/mean': Array(8.4789235e-06, dtype=float32), 'gradients/2/mean': Array(8.9866735e-05, dtype=float32)}
# Step 81: {'train/loss': 4.684552192687988, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.2066939e-05, dtype=float32), 'gradients/1/mean': Array(5.9103754e-06, dtype=float32), 'gradients/2/mean': Array(9.3828734e-05, dtype=float32)}
# Step 82: {'train/loss': 4.678659439086914, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.223889e-05, dtype=float32), 'gradients/1/mean': Array(3.0468677e-06, dtype=float32), 'gradients/2/mean': Array(9.725984e-05, dtype=float32)}
# Step 83: {'train/loss': 4.672786712646484, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.2432643e-05, dtype=float32), 'gradients/1/mean': Array(-1.4763191e-07, dtype=float32), 'gradients/2/mean': Array(0.00010019, dtype=float32)}
# Step 84: {'train/loss': 4.666932582855225, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.264601e-05, dtype=float32), 'gradients/1/mean': Array(-3.7023729e-06, dtype=float32), 'gradients/2/mean': Array(0.00010264, dtype=float32)}
# Step 85: {'train/loss': 4.661098480224609, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.287459e-05, dtype=float32), 'gradients/1/mean': Array(-7.611741e-06, dtype=float32), 'gradients/2/mean': Array(0.00010464, dtype=float32)}
# Step 86: {'train/loss': 4.655288219451904, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3111073e-05, dtype=float32), 'gradients/1/mean': Array(-1.1813825e-05, dtype=float32), 'gradients/2/mean': Array(0.00010621, dtype=float32)}
# Step 87: {'train/loss': 4.649502754211426, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3344914e-05, dtype=float32), 'gradients/1/mean': Array(-1.6184546e-05, dtype=float32), 'gradients/2/mean': Array(0.00010739, dtype=float32)}
# Step 88: {'train/loss': 4.643743991851807, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3562829e-05, dtype=float32), 'gradients/1/mean': Array(-2.0545345e-05, dtype=float32), 'gradients/2/mean': Array(0.00010822, dtype=float32)}
# Step 89: {'train/loss': 4.638012409210205, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3750246e-05, dtype=float32), 'gradients/1/mean': Array(-2.467568e-05, dtype=float32), 'gradients/2/mean': Array(0.00010873, dtype=float32)}
# Step 90: {'train/loss': 4.632312297821045, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.389266e-05, dtype=float32), 'gradients/1/mean': Array(-2.8328464e-05, dtype=float32), 'gradients/2/mean': Array(0.00010901, dtype=float32)}
# Step 91: {'train/loss': 4.626641273498535, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3977665e-05, dtype=float32), 'gradients/1/mean': Array(-3.1256062e-05, dtype=float32), 'gradients/2/mean': Array(0.0001091, dtype=float32)}
# Step 92: {'train/loss': 4.621004104614258, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3995608e-05, dtype=float32), 'gradients/1/mean': Array(-3.3253407e-05, dtype=float32), 'gradients/2/mean': Array(0.0001091, dtype=float32)}
# Step 93: {'train/loss': 4.615400314331055, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3939932e-05, dtype=float32), 'gradients/1/mean': Array(-3.420288e-05, dtype=float32), 'gradients/2/mean': Array(0.00010907, dtype=float32)}
# Step 94: {'train/loss': 4.609830856323242, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.38067e-05, dtype=float32), 'gradients/1/mean': Array(-3.409925e-05, dtype=float32), 'gradients/2/mean': Array(0.00010911, dtype=float32)}
# Step 95: {'train/loss': 4.60429573059082, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.3594168e-05, dtype=float32), 'gradients/1/mean': Array(-3.3046395e-05, dtype=float32), 'gradients/2/mean': Array(0.00010927, dtype=float32)}
# Step 96: {'train/loss': 4.598796844482422, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.330206e-05, dtype=float32), 'gradients/1/mean': Array(-3.123646e-05, dtype=float32), 'gradients/2/mean': Array(0.00010961, dtype=float32)}
# Step 97: {'train/loss': 4.593334197998047, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.2931103e-05, dtype=float32), 'gradients/1/mean': Array(-2.8921897e-05, dtype=float32), 'gradients/2/mean': Array(0.00011015, dtype=float32)}
# Step 98: {'train/loss': 4.587907314300537, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.2482787e-05, dtype=float32), 'gradients/1/mean': Array(-2.6391757e-05, dtype=float32), 'gradients/2/mean': Array(0.00011093, dtype=float32)}
# Step 99: {'train/loss': 4.582516670227051, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1958998e-05, dtype=float32), 'gradients/1/mean': Array(-2.3952134e-05, dtype=float32), 'gradients/2/mean': Array(0.00011193, dtype=float32)}
# Step 100: {'train/loss': 4.57716178894043, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.1362082e-05, dtype=float32), 'gradients/1/mean': Array(-2.190799e-05, dtype=float32), 'gradients/2/mean': Array(0.00011313, dtype=float32)}
# Step 101: {'train/loss': 4.571843147277832, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.0694624e-05, dtype=float32), 'gradients/1/mean': Array(-2.0543297e-05, dtype=float32), 'gradients/2/mean': Array(0.00011451, dtype=float32)}
# Step 102: {'train/loss': 4.566561698913574, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.9959509e-05, dtype=float32), 'gradients/1/mean': Array(-2.0098929e-05, dtype=float32), 'gradients/2/mean': Array(0.00011601, dtype=float32)}
# Step 103: {'train/loss': 4.561314582824707, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.9159763e-05, dtype=float32), 'gradients/1/mean': Array(-2.0747035e-05, dtype=float32), 'gradients/2/mean': Array(0.00011756, dtype=float32)}
# Step 104: {'train/loss': 4.55610466003418, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.8298539e-05, dtype=float32), 'gradients/1/mean': Array(-2.256874e-05, dtype=float32), 'gradients/2/mean': Array(0.00011908, dtype=float32)}
# Step 105: {'train/loss': 4.55092716217041, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.737903e-05, dtype=float32), 'gradients/1/mean': Array(-2.5538267e-05, dtype=float32), 'gradients/2/mean': Array(0.00012045, dtype=float32)}
# Step 106: {'train/loss': 4.545784950256348, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.640432e-05, dtype=float32), 'gradients/1/mean': Array(-2.9521012e-05, dtype=float32), 'gradients/2/mean': Array(0.00012156, dtype=float32)}
# Step 107: {'train/loss': 4.540675640106201, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.5377342e-05, dtype=float32), 'gradients/1/mean': Array(-3.428702e-05, dtype=float32), 'gradients/2/mean': Array(0.00012226, dtype=float32)}
# Step 108: {'train/loss': 4.535600185394287, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.43009e-05, dtype=float32), 'gradients/1/mean': Array(-3.9537565e-05, dtype=float32), 'gradients/2/mean': Array(0.00012241, dtype=float32)}
# Step 109: {'train/loss': 4.5305562019348145, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.317751e-05, dtype=float32), 'gradients/1/mean': Array(-4.494218e-05, dtype=float32), 'gradients/2/mean': Array(0.00012189, dtype=float32)}
# Step 110: {'train/loss': 4.525543689727783, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.2009712e-05, dtype=float32), 'gradients/1/mean': Array(-5.0180282e-05, dtype=float32), 'gradients/2/mean': Array(0.0001206, dtype=float32)}
# Step 111: {'train/loss': 4.520564556121826, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.0799876e-05, dtype=float32), 'gradients/1/mean': Array(-5.4982655e-05, dtype=float32), 'gradients/2/mean': Array(0.00011852, dtype=float32)}
# Step 112: {'train/loss': 4.515614032745361, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-9.550449e-06, dtype=float32), 'gradients/1/mean': Array(-5.9160346e-05, dtype=float32), 'gradients/2/mean': Array(0.00011571, dtype=float32)}
# Step 113: {'train/loss': 4.510695934295654, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-8.264068e-06, dtype=float32), 'gradients/1/mean': Array(-6.2609906e-05, dtype=float32), 'gradients/2/mean': Array(0.00011231, dtype=float32)}
# Step 114: {'train/loss': 4.5058088302612305, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-6.9435987e-06, dtype=float32), 'gradients/1/mean': Array(-6.5292246e-05, dtype=float32), 'gradients/2/mean': Array(0.00010847, dtype=float32)}
# Step 115: {'train/loss': 4.500953674316406, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-5.5921873e-06, dtype=float32), 'gradients/1/mean': Array(-6.71989e-05, dtype=float32), 'gradients/2/mean': Array(0.00010437, dtype=float32)}
# Step 116: {'train/loss': 4.496127605438232, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-4.2134425e-06, dtype=float32), 'gradients/1/mean': Array(-6.8329355e-05, dtype=float32), 'gradients/2/mean': Array(0.00010014, dtype=float32)}
# Step 117: {'train/loss': 4.491333484649658, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.8114077e-06, dtype=float32), 'gradients/1/mean': Array(-6.869255e-05, dtype=float32), 'gradients/2/mean': Array(9.58635e-05, dtype=float32)}
# Step 118: {'train/loss': 4.486569404602051, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.390656e-06, dtype=float32), 'gradients/1/mean': Array(-6.832293e-05, dtype=float32), 'gradients/2/mean': Array(9.156215e-05, dtype=float32)}
# Step 119: {'train/loss': 4.481838226318359, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(4.3697455e-08, dtype=float32), 'gradients/1/mean': Array(-6.730018e-05, dtype=float32), 'gradients/2/mean': Array(8.72351e-05, dtype=float32)}
# Step 120: {'train/loss': 4.477136135101318, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.4860755e-06, dtype=float32), 'gradients/1/mean': Array(-6.5765395e-05, dtype=float32), 'gradients/2/mean': Array(8.285622e-05, dtype=float32)}
# Step 121: {'train/loss': 4.472466945648193, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.9304908e-06, dtype=float32), 'gradients/1/mean': Array(-6.3928725e-05, dtype=float32), 'gradients/2/mean': Array(7.838704e-05, dtype=float32)}
# Step 122: {'train/loss': 4.467828273773193, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(4.3706405e-06, dtype=float32), 'gradients/1/mean': Array(-6.2070445e-05, dtype=float32), 'gradients/2/mean': Array(7.378216e-05, dtype=float32)}
# Step 123: {'train/loss': 4.463221073150635, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(5.8000273e-06, dtype=float32), 'gradients/1/mean': Array(-6.053321e-05, dtype=float32), 'gradients/2/mean': Array(6.8989604e-05, dtype=float32)}
# Step 124: {'train/loss': 4.458644866943359, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(7.212136e-06, dtype=float32), 'gradients/1/mean': Array(-5.970385e-05, dtype=float32), 'gradients/2/mean': Array(6.394925e-05, dtype=float32)}
# Step 125: {'train/loss': 4.454096794128418, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(8.600543e-06, dtype=float32), 'gradients/1/mean': Array(-5.997475e-05, dtype=float32), 'gradients/2/mean': Array(5.8591388e-05, dtype=float32)}
# Step 126: {'train/loss': 4.449581623077393, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(9.958829e-06, dtype=float32), 'gradients/1/mean': Array(-6.167992e-05, dtype=float32), 'gradients/2/mean': Array(5.283574e-05, dtype=float32)}
# Step 127: {'train/loss': 4.445094108581543, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.1280841e-05, dtype=float32), 'gradients/1/mean': Array(-6.500117e-05, dtype=float32), 'gradients/2/mean': Array(4.6595218e-05, dtype=float32)}
# Step 128: {'train/loss': 4.440637111663818, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.2560586e-05, dtype=float32), 'gradients/1/mean': Array(-6.988174e-05, dtype=float32), 'gradients/2/mean': Array(3.9783496e-05, dtype=float32)}
# Step 129: {'train/loss': 4.436206817626953, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.3792295e-05, dtype=float32), 'gradients/1/mean': Array(-7.601256e-05, dtype=float32), 'gradients/2/mean': Array(3.232681e-05, dtype=float32)}
# Step 130: {'train/loss': 4.431804656982422, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.4970396e-05, dtype=float32), 'gradients/1/mean': Array(-8.292199e-05, dtype=float32), 'gradients/2/mean': Array(2.4177833e-05, dtype=float32)}
# Step 131: {'train/loss': 4.427428245544434, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.6089449e-05, dtype=float32), 'gradients/1/mean': Array(-9.011975e-05, dtype=float32), 'gradients/2/mean': Array(1.5328493e-05, dtype=float32)}
# Step 132: {'train/loss': 4.4230756759643555, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.7144239e-05, dtype=float32), 'gradients/1/mean': Array(-9.719575e-05, dtype=float32), 'gradients/2/mean': Array(5.817732e-06, dtype=float32)}
# Step 133: {'train/loss': 4.4187493324279785, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.812985e-05, dtype=float32), 'gradients/1/mean': Array(-0.00010385, dtype=float32), 'gradients/2/mean': Array(-4.2677284e-06, dtype=float32)}
# Step 134: {'train/loss': 4.414443016052246, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.9041589e-05, dtype=float32), 'gradients/1/mean': Array(-0.00010989, dtype=float32), 'gradients/2/mean': Array(-1.4800606e-05, dtype=float32)}
# Step 135: {'train/loss': 4.410158157348633, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.987538e-05, dtype=float32), 'gradients/1/mean': Array(-0.0001152, dtype=float32), 'gradients/2/mean': Array(-2.5626934e-05, dtype=float32)}
# Step 136: {'train/loss': 4.405892372131348, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.0627644e-05, dtype=float32), 'gradients/1/mean': Array(-0.00011977, dtype=float32), 'gradients/2/mean': Array(-3.6580077e-05, dtype=float32)}
# Step 137: {'train/loss': 4.4016432762146, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.1295647e-05, dtype=float32), 'gradients/1/mean': Array(-0.00012363, dtype=float32), 'gradients/2/mean': Array(-4.749524e-05, dtype=float32)}
# Step 138: {'train/loss': 4.397409915924072, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.1877466e-05, dtype=float32), 'gradients/1/mean': Array(-0.00012694, dtype=float32), 'gradients/2/mean': Array(-5.821798e-05, dtype=float32)}
# Step 139: {'train/loss': 4.393193244934082, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2372371e-05, dtype=float32), 'gradients/1/mean': Array(-0.00012987, dtype=float32), 'gradients/2/mean': Array(-6.861013e-05, dtype=float32)}
# Step 140: {'train/loss': 4.3889875411987305, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2780778e-05, dtype=float32), 'gradients/1/mean': Array(-0.00013262, dtype=float32), 'gradients/2/mean': Array(-7.855077e-05, dtype=float32)}
# Step 141: {'train/loss': 4.384795188903809, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.3104583e-05, dtype=float32), 'gradients/1/mean': Array(-0.00013538, dtype=float32), 'gradients/2/mean': Array(-8.7935856e-05, dtype=float32)}
# Step 142: {'train/loss': 4.380612373352051, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.3347093e-05, dtype=float32), 'gradients/1/mean': Array(-0.00013825, dtype=float32), 'gradients/2/mean': Array(-9.667665e-05, dtype=float32)}
# Step 143: {'train/loss': 4.37644100189209, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.3513245e-05, dtype=float32), 'gradients/1/mean': Array(-0.00014126, dtype=float32), 'gradients/2/mean': Array(-0.0001047, dtype=float32)}
# Step 144: {'train/loss': 4.372278213500977, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.3609478e-05, dtype=float32), 'gradients/1/mean': Array(-0.00014438, dtype=float32), 'gradients/2/mean': Array(-0.00011194, dtype=float32)}
# Step 145: {'train/loss': 4.368122100830078, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.3643848e-05, dtype=float32), 'gradients/1/mean': Array(-0.00014752, dtype=float32), 'gradients/2/mean': Array(-0.00011834, dtype=float32)}
# Step 146: {'train/loss': 4.363976001739502, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.3625604e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015059, dtype=float32), 'gradients/2/mean': Array(-0.00012384, dtype=float32)}
# Step 147: {'train/loss': 4.359836101531982, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.356513e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015346, dtype=float32), 'gradients/2/mean': Array(-0.00012838, dtype=float32)}
# Step 148: {'train/loss': 4.3557024002075195, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.3473456e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015603, dtype=float32), 'gradients/2/mean': Array(-0.00013189, dtype=float32)}
# Step 149: {'train/loss': 4.351574897766113, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.3361732e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015816, dtype=float32), 'gradients/2/mean': Array(-0.00013426, dtype=float32)}
# Step 150: {'train/loss': 4.347454071044922, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.3240567e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015974, dtype=float32), 'gradients/2/mean': Array(-0.0001354, dtype=float32)}
# Step 151: {'train/loss': 4.343339920043945, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.31193e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016065, dtype=float32), 'gradients/2/mean': Array(-0.00013522, dtype=float32)}
# Step 152: {'train/loss': 4.339228630065918, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.300519e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016079, dtype=float32), 'gradients/2/mean': Array(-0.00013368, dtype=float32)}
# Step 153: {'train/loss': 4.3351240158081055, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2902992e-05, dtype=float32), 'gradients/1/mean': Array(-0.00016007, dtype=float32), 'gradients/2/mean': Array(-0.00013085, dtype=float32)}
# Step 154: {'train/loss': 4.331025123596191, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2814438e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015842, dtype=float32), 'gradients/2/mean': Array(-0.00012699, dtype=float32)}
# Step 155: {'train/loss': 4.326929092407227, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2738719e-05, dtype=float32), 'gradients/1/mean': Array(-0.00015582, dtype=float32), 'gradients/2/mean': Array(-0.00012248, dtype=float32)}
# Step 156: {'train/loss': 4.3228373527526855, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.267284e-05, dtype=float32), 'gradients/1/mean': Array(-0.0001523, dtype=float32), 'gradients/2/mean': Array(-0.00011777, dtype=float32)}
# Step 157: {'train/loss': 4.31874942779541, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.26128e-05, dtype=float32), 'gradients/1/mean': Array(-0.00014799, dtype=float32), 'gradients/2/mean': Array(-0.00011331, dtype=float32)}
# Step 158: {'train/loss': 4.314664840698242, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2554517e-05, dtype=float32), 'gradients/1/mean': Array(-0.00014309, dtype=float32), 'gradients/2/mean': Array(-0.00010941, dtype=float32)}
# Step 159: {'train/loss': 4.310582637786865, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2494733e-05, dtype=float32), 'gradients/1/mean': Array(-0.0001379, dtype=float32), 'gradients/2/mean': Array(-0.00010625, dtype=float32)}
# Step 160: {'train/loss': 4.3065009117126465, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2431404e-05, dtype=float32), 'gradients/1/mean': Array(-0.00013276, dtype=float32), 'gradients/2/mean': Array(-0.00010386, dtype=float32)}
# Step 161: {'train/loss': 4.302422046661377, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2363698e-05, dtype=float32), 'gradients/1/mean': Array(-0.00012799, dtype=float32), 'gradients/2/mean': Array(-0.00010214, dtype=float32)}
# Step 162: {'train/loss': 4.298344135284424, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2291251e-05, dtype=float32), 'gradients/1/mean': Array(-0.00012387, dtype=float32), 'gradients/2/mean': Array(-0.00010089, dtype=float32)}
# Step 163: {'train/loss': 4.294267654418945, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2213499e-05, dtype=float32), 'gradients/1/mean': Array(-0.00012056, dtype=float32), 'gradients/2/mean': Array(-9.990334e-05, dtype=float32)}
# Step 164: {'train/loss': 4.290192127227783, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.212875e-05, dtype=float32), 'gradients/1/mean': Array(-0.00011807, dtype=float32), 'gradients/2/mean': Array(-9.902806e-05, dtype=float32)}
# Step 165: {'train/loss': 4.28611946105957, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.2033912e-05, dtype=float32), 'gradients/1/mean': Array(-0.00011619, dtype=float32), 'gradients/2/mean': Array(-9.824548e-05, dtype=float32)}
# Step 166: {'train/loss': 4.282044410705566, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.1924618e-05, dtype=float32), 'gradients/1/mean': Array(-0.00011457, dtype=float32), 'gradients/2/mean': Array(-9.766622e-05, dtype=float32)}
# Step 167: {'train/loss': 4.277970790863037, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.1796028e-05, dtype=float32), 'gradients/1/mean': Array(-0.0001128, dtype=float32), 'gradients/2/mean': Array(-9.747157e-05, dtype=float32)}
# Step 168: {'train/loss': 4.273898124694824, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.1643442e-05, dtype=float32), 'gradients/1/mean': Array(-0.00011045, dtype=float32), 'gradients/2/mean': Array(-9.780479e-05, dtype=float32)}
# Step 169: {'train/loss': 4.269824028015137, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.1462882e-05, dtype=float32), 'gradients/1/mean': Array(-0.00010724, dtype=float32), 'gradients/2/mean': Array(-9.865661e-05, dtype=float32)}
# Step 170: {'train/loss': 4.265751838684082, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.1251093e-05, dtype=float32), 'gradients/1/mean': Array(-0.000103, dtype=float32), 'gradients/2/mean': Array(-9.980939e-05, dtype=float32)}
# Step 171: {'train/loss': 4.261678218841553, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.1005191e-05, dtype=float32), 'gradients/1/mean': Array(-9.7735145e-05, dtype=float32), 'gradients/2/mean': Array(-0.00010088, dtype=float32)}
# Step 172: {'train/loss': 4.257606029510498, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.0722262e-05, dtype=float32), 'gradients/1/mean': Array(-9.1535985e-05, dtype=float32), 'gradients/2/mean': Array(-0.00010147, dtype=float32)}
# Step 173: {'train/loss': 4.253532886505127, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.0399162e-05, dtype=float32), 'gradients/1/mean': Array(-8.449304e-05, dtype=float32), 'gradients/2/mean': Array(-0.00010129, dtype=float32)}
# Step 174: {'train/loss': 4.249460220336914, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(2.0032665e-05, dtype=float32), 'gradients/1/mean': Array(-7.664333e-05, dtype=float32), 'gradients/2/mean': Array(-0.00010036, dtype=float32)}
# Step 175: {'train/loss': 4.245389938354492, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.96203e-05, dtype=float32), 'gradients/1/mean': Array(-6.797403e-05, dtype=float32), 'gradients/2/mean': Array(-9.8937286e-05, dtype=float32)}
# Step 176: {'train/loss': 4.241320610046387, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.916155e-05, dtype=float32), 'gradients/1/mean': Array(-5.8491933e-05, dtype=float32), 'gradients/2/mean': Array(-9.743472e-05, dtype=float32)}
# Step 177: {'train/loss': 4.237253189086914, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.8658862e-05, dtype=float32), 'gradients/1/mean': Array(-4.83209e-05, dtype=float32), 'gradients/2/mean': Array(-9.617946e-05, dtype=float32)}
# Step 178: {'train/loss': 4.233188152313232, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.8118364e-05, dtype=float32), 'gradients/1/mean': Array(-3.7772294e-05, dtype=float32), 'gradients/2/mean': Array(-9.523616e-05, dtype=float32)}
# Step 179: {'train/loss': 4.2291259765625, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.7549231e-05, dtype=float32), 'gradients/1/mean': Array(-2.733401e-05, dtype=float32), 'gradients/2/mean': Array(-9.4391675e-05, dtype=float32)}
# Step 180: {'train/loss': 4.225067138671875, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.6962487e-05, dtype=float32), 'gradients/1/mean': Array(-1.7561726e-05, dtype=float32), 'gradients/2/mean': Array(-9.331404e-05, dtype=float32)}
# Step 181: {'train/loss': 4.221013069152832, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.6368762e-05, dtype=float32), 'gradients/1/mean': Array(-8.910473e-06, dtype=float32), 'gradients/2/mean': Array(-9.17883e-05, dtype=float32)}
# Step 182: {'train/loss': 4.216961860656738, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.5776524e-05, dtype=float32), 'gradients/1/mean': Array(-1.5982359e-06, dtype=float32), 'gradients/2/mean': Array(-8.988157e-05, dtype=float32)}
# Step 183: {'train/loss': 4.212917327880859, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.5191161e-05, dtype=float32), 'gradients/1/mean': Array(4.4155663e-06, dtype=float32), 'gradients/2/mean': Array(-8.7908586e-05, dtype=float32)}
# Step 184: {'train/loss': 4.2088775634765625, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.4615608e-05, dtype=float32), 'gradients/1/mean': Array(9.319237e-06, dtype=float32), 'gradients/2/mean': Array(-8.622087e-05, dtype=float32)}
# Step 185: {'train/loss': 4.204842567443848, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.4051425e-05, dtype=float32), 'gradients/1/mean': Array(1.3273235e-05, dtype=float32), 'gradients/2/mean': Array(-8.495986e-05, dtype=float32)}
# Step 186: {'train/loss': 4.200813293457031, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.3500045e-05, dtype=float32), 'gradients/1/mean': Array(1.629323e-05, dtype=float32), 'gradients/2/mean': Array(-8.39446e-05, dtype=float32)}
# Step 187: {'train/loss': 4.196789741516113, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.2962844e-05, dtype=float32), 'gradients/1/mean': Array(1.8272243e-05, dtype=float32), 'gradients/2/mean': Array(-8.277162e-05, dtype=float32)}
# Step 188: {'train/loss': 4.192771911621094, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.244046e-05, dtype=float32), 'gradients/1/mean': Array(1.9122735e-05, dtype=float32), 'gradients/2/mean': Array(-8.107679e-05, dtype=float32)}
# Step 189: {'train/loss': 4.188760757446289, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.19322e-05, dtype=float32), 'gradients/1/mean': Array(1.8923227e-05, dtype=float32), 'gradients/2/mean': Array(-7.8767865e-05, dtype=float32)}
# Step 190: {'train/loss': 4.184753894805908, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.1436598e-05, dtype=float32), 'gradients/1/mean': Array(1.7947083e-05, dtype=float32), 'gradients/2/mean': Array(-7.605053e-05, dtype=float32)}
# Step 191: {'train/loss': 4.180752754211426, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.0953466e-05, dtype=float32), 'gradients/1/mean': Array(1.6541537e-05, dtype=float32), 'gradients/2/mean': Array(-7.323575e-05, dtype=float32)}
# Step 192: {'train/loss': 4.176755905151367, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.048622e-05, dtype=float32), 'gradients/1/mean': Array(1.4945592e-05, dtype=float32), 'gradients/2/mean': Array(-7.0518254e-05, dtype=float32)}
# Step 193: {'train/loss': 4.172764778137207, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.0042851e-05, dtype=float32), 'gradients/1/mean': Array(1.3183884e-05, dtype=float32), 'gradients/2/mean': Array(-6.7898145e-05, dtype=float32)}
# Step 194: {'train/loss': 4.168777942657471, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(9.6349295e-06, dtype=float32), 'gradients/1/mean': Array(1.1135544e-05, dtype=float32), 'gradients/2/mean': Array(-6.527987e-05, dtype=float32)}
# Step 195: {'train/loss': 4.164795398712158, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(9.27488e-06, dtype=float32), 'gradients/1/mean': Array(8.7326325e-06, dtype=float32), 'gradients/2/mean': Array(-6.262918e-05, dtype=float32)}
# Step 196: {'train/loss': 4.160816192626953, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(8.973124e-06, dtype=float32), 'gradients/1/mean': Array(6.1208902e-06, dtype=float32), 'gradients/2/mean': Array(-6.004115e-05, dtype=float32)}
# ...
# Step 2114: {'train/loss': 1.6206871271133423, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.5165383e-06, dtype=float32), 'gradients/1/mean': Array(2.188569e-05, dtype=float32), 'gradients/2/mean': Array(2.1784888e-05, dtype=float32)}
# Step 2115: {'train/loss': 1.6199108362197876, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-3.5504506e-06, dtype=float32), 'gradients/1/mean': Array(1.9653366e-05, dtype=float32), 'gradients/2/mean': Array(1.5260972e-05, dtype=float32)}
# Step 2116: {'train/loss': 1.6195231676101685, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.854098e-07, dtype=float32), 'gradients/1/mean': Array(-6.1480955e-06, dtype=float32), 'gradients/2/mean': Array(4.9920554e-06, dtype=float32)}
# Step 2117: {'train/loss': 1.6188288927078247, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(3.2899254e-06, dtype=float32), 'gradients/1/mean': Array(-1.5295378e-05, dtype=float32), 'gradients/2/mean': Array(-1.5645719e-05, dtype=float32)}
# Step 2118: {'train/loss': 1.618281364440918, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.7075557e-06, dtype=float32), 'gradients/1/mean': Array(-1.22354695e-05, dtype=float32), 'gradients/2/mean': Array(-1.2675512e-05, dtype=float32)}
# Step 2119: {'train/loss': 1.6178160905838013, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.0437834e-06, dtype=float32), 'gradients/1/mean': Array(-5.4953584e-06, dtype=float32), 'gradients/2/mean': Array(1.1424326e-05, dtype=float32)}
# Step 2120: {'train/loss': 1.617424726486206, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-3.5126757e-06, dtype=float32), 'gradients/1/mean': Array(-1.6437266e-06, dtype=float32), 'gradients/2/mean': Array(2.4946878e-05, dtype=float32)}
# Step 2121: {'train/loss': 1.6168689727783203, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-7.921373e-06, dtype=float32), 'gradients/1/mean': Array(3.214527e-06, dtype=float32), 'gradients/2/mean': Array(1.14988225e-05, dtype=float32)}
# Step 2122: {'train/loss': 1.6164942979812622, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.577134e-05, dtype=float32), 'gradients/1/mean': Array(7.85397e-06, dtype=float32), 'gradients/2/mean': Array(-7.667191e-06, dtype=float32)}
# Step 2123: {'train/loss': 1.61588454246521, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.5669311e-05, dtype=float32), 'gradients/1/mean': Array(6.9594917e-06, dtype=float32), 'gradients/2/mean': Array(-5.2453283e-06, dtype=float32)}
# Step 2124: {'train/loss': 1.6155933141708374, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-8.8134975e-06, dtype=float32), 'gradients/1/mean': Array(6.948626e-06, dtype=float32), 'gradients/2/mean': Array(1.2974012e-06, dtype=float32)}
# Step 2125: {'train/loss': 1.6150249242782593, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-6.6228704e-06, dtype=float32), 'gradients/1/mean': Array(5.9877734e-06, dtype=float32), 'gradients/2/mean': Array(1.1142037e-06, dtype=float32)}
# Step 2126: {'train/loss': 1.6146774291992188, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.01975875e-05, dtype=float32), 'gradients/1/mean': Array(-2.983141e-06, dtype=float32), 'gradients/2/mean': Array(1.3548288e-08, dtype=float32)}
# Step 2127: {'train/loss': 1.6141585111618042, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.1211895e-05, dtype=float32), 'gradients/1/mean': Array(-1.164876e-05, dtype=float32), 'gradients/2/mean': Array(8.9701325e-07, dtype=float32)}
# Step 2128: {'train/loss': 1.6137545108795166, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-8.096846e-06, dtype=float32), 'gradients/1/mean': Array(-9.5394225e-06, dtype=float32), 'gradients/2/mean': Array(6.3435923e-06, dtype=float32)}
# Step 2129: {'train/loss': 1.6134636402130127, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-4.360049e-06, dtype=float32), 'gradients/1/mean': Array(6.8259936e-07, dtype=float32), 'gradients/2/mean': Array(1.3714206e-05, dtype=float32)}
# Step 2130: {'train/loss': 1.6129646301269531, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.9291524e-06, dtype=float32), 'gradients/1/mean': Array(7.381237e-06, dtype=float32), 'gradients/2/mean': Array(1.014019e-05, dtype=float32)}
# Step 2131: {'train/loss': 1.6126372814178467, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-5.184064e-06, dtype=float32), 'gradients/1/mean': Array(7.7126015e-06, dtype=float32), 'gradients/2/mean': Array(2.7354463e-06, dtype=float32)}
# Step 2132: {'train/loss': 1.6121680736541748, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.33051235e-05, dtype=float32), 'gradients/1/mean': Array(6.0547427e-06, dtype=float32), 'gradients/2/mean': Array(2.9641035e-06, dtype=float32)}
# Step 2133: {'train/loss': 1.6117708683013916, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.2102919e-05, dtype=float32), 'gradients/1/mean': Array(4.1558537e-06, dtype=float32), 'gradients/2/mean': Array(8.468907e-06, dtype=float32)}
# Step 2134: {'train/loss': 1.6114301681518555, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-4.8085885e-06, dtype=float32), 'gradients/1/mean': Array(4.8181223e-06, dtype=float32), 'gradients/2/mean': Array(6.98883e-06, dtype=float32)}
# Step 2135: {'train/loss': 1.6110632419586182, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-7.459188e-06, dtype=float32), 'gradients/1/mean': Array(4.277936e-06, dtype=float32), 'gradients/2/mean': Array(2.982719e-06, dtype=float32)}
# Step 2136: {'train/loss': 1.6106704473495483, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.39270405e-05, dtype=float32), 'gradients/1/mean': Array(-8.144568e-07, dtype=float32), 'gradients/2/mean': Array(3.865846e-06, dtype=float32)}
# Step 2137: {'train/loss': 1.610273003578186, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.7310953e-05, dtype=float32), 'gradients/1/mean': Array(-3.1978436e-06, dtype=float32), 'gradients/2/mean': Array(1.0568418e-05, dtype=float32)}
# Step 2138: {'train/loss': 1.609902262687683, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.4170637e-05, dtype=float32), 'gradients/1/mean': Array(-1.7184561e-06, dtype=float32), 'gradients/2/mean': Array(1.4202656e-05, dtype=float32)}
# Step 2139: {'train/loss': 1.6095778942108154, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-8.085851e-06, dtype=float32), 'gradients/1/mean': Array(-2.2397453e-06, dtype=float32), 'gradients/2/mean': Array(2.1188362e-06, dtype=float32)}
# Step 2140: {'train/loss': 1.6092392206192017, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-8.777094e-06, dtype=float32), 'gradients/1/mean': Array(5.3433423e-06, dtype=float32), 'gradients/2/mean': Array(-4.563349e-06, dtype=float32)}
# Step 2141: {'train/loss': 1.6091269254684448, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-5.1410575e-06, dtype=float32), 'gradients/1/mean': Array(-4.3818873e-06, dtype=float32), 'gradients/2/mean': Array(-2.3569746e-06, dtype=float32)}
# Step 2142: {'train/loss': 1.6092543601989746, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.354973e-05, dtype=float32), 'gradients/1/mean': Array(1.2590044e-05, dtype=float32), 'gradients/2/mean': Array(-6.3743432e-06, dtype=float32)}
# Step 2143: {'train/loss': 1.6097402572631836, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-5.281415e-06, dtype=float32), 'gradients/1/mean': Array(2.1858427e-06, dtype=float32), 'gradients/2/mean': Array(3.0191861e-06, dtype=float32)}
# Step 2144: {'train/loss': 1.6090962886810303, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-7.6983015e-06, dtype=float32), 'gradients/1/mean': Array(-3.4341917e-07, dtype=float32), 'gradients/2/mean': Array(-1.325367e-05, dtype=float32)}
# Step 2145: {'train/loss': 1.6081300973892212, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.29648e-05, dtype=float32), 'gradients/1/mean': Array(-5.073713e-08, dtype=float32), 'gradients/2/mean': Array(-1.0584753e-05, dtype=float32)}
# Step 2146: {'train/loss': 1.6080870628356934, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-7.1088093e-06, dtype=float32), 'gradients/1/mean': Array(2.094239e-06, dtype=float32), 'gradients/2/mean': Array(1.2629174e-05, dtype=float32)}
# Step 2147: {'train/loss': 1.607560157775879, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(3.2922517e-06, dtype=float32), 'gradients/1/mean': Array(1.6682247e-06, dtype=float32), 'gradients/2/mean': Array(1.1236715e-05, dtype=float32)}
# Step 2148: {'train/loss': 1.6070771217346191, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-4.0551863e-06, dtype=float32), 'gradients/1/mean': Array(-3.7125965e-06, dtype=float32), 'gradients/2/mean': Array(1.5517401e-06, dtype=float32)}
# Step 2149: {'train/loss': 1.6068693399429321, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-9.004897e-06, dtype=float32), 'gradients/1/mean': Array(-9.988132e-06, dtype=float32), 'gradients/2/mean': Array(1.1992873e-05, dtype=float32)}
# Step 2150: {'train/loss': 1.6062920093536377, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-6.820845e-07, dtype=float32), 'gradients/1/mean': Array(-6.0048133e-06, dtype=float32), 'gradients/2/mean': Array(8.894484e-07, dtype=float32)}
# Step 2151: {'train/loss': 1.6057319641113281, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-5.0982117e-06, dtype=float32), 'gradients/1/mean': Array(3.0631313e-06, dtype=float32), 'gradients/2/mean': Array(-3.4575035e-06, dtype=float32)}
# Step 2152: {'train/loss': 1.6056456565856934, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.6205739e-05, dtype=float32), 'gradients/1/mean': Array(3.0955616e-06, dtype=float32), 'gradients/2/mean': Array(1.05418585e-05, dtype=float32)}
# Step 2153: {'train/loss': 1.6052883863449097, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-8.3276e-06, dtype=float32), 'gradients/1/mean': Array(-1.5620523e-06, dtype=float32), 'gradients/2/mean': Array(-6.9107955e-07, dtype=float32)}
# Step 2154: {'train/loss': 1.6046215295791626, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-3.2221499e-06, dtype=float32), 'gradients/1/mean': Array(-4.989846e-06, dtype=float32), 'gradients/2/mean': Array(-1.4813764e-07, dtype=float32)}
# Step 2155: {'train/loss': 1.6043668985366821, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.1289623e-05, dtype=float32), 'gradients/1/mean': Array(-1.69794e-06, dtype=float32), 'gradients/2/mean': Array(1.019621e-05, dtype=float32)}
# Step 2156: {'train/loss': 1.6040089130401611, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-6.0729494e-06, dtype=float32), 'gradients/1/mean': Array(4.463431e-06, dtype=float32), 'gradients/2/mean': Array(5.921069e-06, dtype=float32)}
# Step 2157: {'train/loss': 1.6036678552627563, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.9668119e-06, dtype=float32), 'gradients/1/mean': Array(-9.850164e-07, dtype=float32), 'gradients/2/mean': Array(7.746519e-06, dtype=float32)}
# Step 2158: {'train/loss': 1.6032267808914185, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-4.6473538e-06, dtype=float32), 'gradients/1/mean': Array(-2.6214275e-06, dtype=float32), 'gradients/2/mean': Array(1.4038369e-06, dtype=float32)}
# Step 2159: {'train/loss': 1.6027655601501465, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-9.6771755e-06, dtype=float32), 'gradients/1/mean': Array(2.3967273e-06, dtype=float32), 'gradients/2/mean': Array(-9.34415e-06, dtype=float32)}
# Step 2160: {'train/loss': 1.6027355194091797, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.0844232e-06, dtype=float32), 'gradients/1/mean': Array(1.2258367e-06, dtype=float32), 'gradients/2/mean': Array(-2.3150576e-06, dtype=float32)}
# Step 2161: {'train/loss': 1.6024863719940186, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.075658e-05, dtype=float32), 'gradients/1/mean': Array(-1.332952e-07, dtype=float32), 'gradients/2/mean': Array(2.1050364e-06, dtype=float32)}
# Step 2162: {'train/loss': 1.6017885208129883, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.36734425e-05, dtype=float32), 'gradients/1/mean': Array(-6.693715e-06, dtype=float32), 'gradients/2/mean': Array(7.020031e-06, dtype=float32)}
# Step 2163: {'train/loss': 1.601619005203247, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-4.9647465e-06, dtype=float32), 'gradients/1/mean': Array(-2.5910795e-06, dtype=float32), 'gradients/2/mean': Array(1.5694947e-06, dtype=float32)}
# Step 2164: {'train/loss': 1.6014254093170166, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-4.4287567e-06, dtype=float32), 'gradients/1/mean': Array(5.3258536e-06, dtype=float32), 'gradients/2/mean': Array(2.9317066e-06, dtype=float32)}
# Step 2165: {'train/loss': 1.6011857986450195, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-5.4342986e-06, dtype=float32), 'gradients/1/mean': Array(-4.1653707e-06, dtype=float32), 'gradients/2/mean': Array(9.1594775e-06, dtype=float32)}
# Step 2166: {'train/loss': 1.6005744934082031, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-9.2195205e-06, dtype=float32), 'gradients/1/mean': Array(9.798141e-07, dtype=float32), 'gradients/2/mean': Array(-3.987501e-06, dtype=float32)}
# Step 2167: {'train/loss': 1.6002269983291626, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-3.996702e-06, dtype=float32), 'gradients/1/mean': Array(2.490031e-06, dtype=float32), 'gradients/2/mean': Array(-3.199568e-06, dtype=float32)}
# Step 2168: {'train/loss': 1.5998225212097168, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-3.3571705e-06, dtype=float32), 'gradients/1/mean': Array(-2.5047266e-06, dtype=float32), 'gradients/2/mean': Array(5.1529187e-06, dtype=float32)}
# Step 2169: {'train/loss': 1.5995616912841797, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.1332355e-05, dtype=float32), 'gradients/1/mean': Array(-5.645514e-07, dtype=float32), 'gradients/2/mean': Array(1.5069634e-06, dtype=float32)}
# Step 2170: {'train/loss': 1.598987340927124, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.2395064e-05, dtype=float32), 'gradients/1/mean': Array(2.4577414e-06, dtype=float32), 'gradients/2/mean': Array(5.1876377e-06, dtype=float32)}
# Step 2171: {'train/loss': 1.5988091230392456, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-2.922847e-06, dtype=float32), 'gradients/1/mean': Array(2.7213932e-06, dtype=float32), 'gradients/2/mean': Array(2.6166963e-06, dtype=float32)}
# Step 2172: {'train/loss': 1.5983707904815674, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-8.318865e-06, dtype=float32), 'gradients/1/mean': Array(-1.0161568e-06, dtype=float32), 'gradients/2/mean': Array(1.6658036e-06, dtype=float32)}
# Step 2173: {'train/loss': 1.5979764461517334, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-1.2028181e-05, dtype=float32), 'gradients/1/mean': Array(5.591552e-07, dtype=float32), 'gradients/2/mean': Array(3.3191875e-06, dtype=float32)}
# Step 2174: {'train/loss': 1.5976884365081787, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-8.961235e-07, dtype=float32), 'gradients/1/mean': Array(5.09276e-06, dtype=float32), 'gradients/2/mean': Array(8.995169e-06, dtype=float32)}
# Step 2175: {'train/loss': 1.5971421003341675, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(1.5949034e-06, dtype=float32), 'gradients/1/mean': Array(1.1136292e-06, dtype=float32), 'gradients/2/mean': Array(9.838503e-06, dtype=float32)}
# Step 2176: {'train/loss': 1.596973180770874, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-6.36517e-06, dtype=float32), 'gradients/1/mean': Array(-1.3226829e-06, dtype=float32), 'gradients/2/mean': Array(-4.018758e-07, dtype=float32)}
# Step 2177: {'train/loss': 1.5964748859405518, 'train/learning_rate': 0.001, 'gradients/0/mean': Array(-6.0022603e-06, dtype=float32), 'gradients/1/mean': Array(-4.468542e-06, dtype=float32), 'gradients/2/mean': Array(8.7438866e-07, dtype=float32)}

# %%
# %debug
